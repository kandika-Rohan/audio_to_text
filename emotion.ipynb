# %% [markdown]
# <a href="https://colab.research.google.com/github/kandika-Rohan/audio_to_text/blob/emotion_added/emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --------------------------
# 2. EMOTION DATASET PREPARATION
# --------------------------
# Download and extract RAVDESS emotional speech dataset
# !wget https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip
# !unzip -q Audio_Speech_Actors_01-24.zip -d "/content/emotion_dataset"

def load_emotion_data(dataset_path):
    emotions = []
    features = []

    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".wav"):
                emotion_code = int(file.split("-")[2])
                emotions.append({
                    1: 'neutral', 2: 'calm', 3: 'happy',
                    4: 'sad', 5: 'angry', 6: 'fear',
                    7: 'disgust', 8: 'surprise'
                }[emotion_code])

                # Load and preprocess audio
                file_path = os.path.join(root, file)
                y, sr = librosa.load(file_path, sr=22050)
                y = nr.reduce_noise(y=y, sr=sr)

                # Extract MFCC features
                mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
                mfcc_processed = np.mean(mfcc.T, axis=0)

                features.append(mfcc_processed)

    return np.array(features), np.array(emotions)

# Load and prepare dataset
print("Loading emotion dataset...")
features, emotions = load_emotion_data("/content/emotion_dataset")

# Encode labels
label_encoder = LabelEncoder()
encoded_emotions = label_encoder.fit_transform(emotions)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    features, encoded_emotions, test_size=0.2, random_state=42
)

# --------------------------
# 3. EMOTION RECOGNITION MODEL
# --------------------------
def create_emotion_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Create and train model
print("Training emotion recognition model...")
model = create_emotion_model((X_train.shape[1],), len(label_encoder.classes_))
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    verbose=1
)

# Save model
model.save('/content/drive/MyDrive/emotion_model.h5')

# --------------------------
# 4. AUDIO PROCESSING PIPELINE
# --------------------------
class SafetyAnalyzer:
    def _init_(self):
        self.panic_words = {
            "help", "fire", "emergency", "danger", "run", "stop", "police",
            "watch out", "look out", "get down", "move", "duck", "stay back",
            "back off", "stay away", "call 911", "call an ambulance",
            "call the police", "call for help", "mayday", "sos", "alert"
        }
        self.whisper_model = whisper.load_model("base")
        self.emotion_model = tf.keras.models.load_model('/content/drive/MyDrive/emotion_model.h5')
        self.label_encoder = label_encoder

    def process_audio(self, input_path):
        # Convert to WAV
        if input_path.endswith(".opus"):
            audio = AudioSegment.from_file(input_path)
            wav_path = input_path.replace(".opus", ".wav")
            audio.export(wav_path, format="wav")
            os.remove(input_path)
            input_path = wav_path

        # Noise reduction
        y, sr = librosa.load(input_path, sr=22050)
        y_clean = nr.reduce_noise(y=y, sr=sr)
        clean_path = input_path.replace(".wav", "_clean.wav")
        sf.write(clean_path, y_clean, sr)

        return clean_path

    def analyze_emotion(self, audio_path):
        y, sr = librosa.load(audio_path, sr=22050)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
        features = np.mean(mfcc.T, axis=0)
        prediction = self.emotion_model.predict(np.expand_dims(features, axis=0))
        emotion = self.label_encoder.inverse_transform([np.argmax(prediction)])[0]
        confidence = np.max(prediction)
        return emotion, confidence

    def transcribe_audio(self, audio_path):
        result = self.whisper_model.transcribe(audio_path)
        return result["text"]

    def analyze_safety(self, audio_path):
        # Process audio
        clean_path = self.process_audio(audio_path)

        # Emotion analysis
        emotion, confidence = self.analyze_emotion(clean_path)

        # Transcription analysis
        transcription = self.transcribe_audio(clean_path)
        panic_detected = [word for word in self.panic_words
                          if word in transcription.lower()]

        # Generate report
        report = {
            "file_path": audio_path,
            "emotion": emotion,
            "confidence": float(confidence),
            "transcription": transcription,
            "panic_words": panic_detected,
            "requires_attention": any(panic_detected) or emotion in ['fear', 'angry']
        }

        return report

# --------------------------
# 5. MAIN EXECUTION
# --------------------------
def analyze_directory(directory_path):
    analyzer = SafetyAnalyzer()
    results = []

    for root, _, files in os.walk(directory_path):
        for file in files:
            if file.endswith((".wav", ".opus")):
                file_path = os.path.join(root, file)
                try:
                    report = analyzer.analyze_safety(file_path)
                    results.append(report)

                    if report["requires_attention"]:
                        print(f"🚨 SAFETY ALERT: {file_path}")
                        print(f"Detected emotion: {report['emotion']} ({report['confidence']:.2%})")
                        print(f"Panic words detected: {report['panic_words']}")
                        print(f"Transcription: {report['transcription']}\n")

                except Exception as e:
                    print(f"Error processing {file_path}: {str(e)}")

    return results

# Run analysis on your audio directory
audio_directory = "/content/drive/MyDrive/audiosdata/audiototext/audio data"
results = analyze_directory(audio_directory)

# --------------------------
# 6. VISUALIZATION
# --------------------------
def visualize_results(results):
    emotions = [r['emotion'] for r in results]
    alerts = [r['requires_attention'] for r in results]

    plt.figure(figsize=(15, 5))

    # Emotion distribution
    plt.subplot(1, 2, 1)
    pd.Series(emotions).value_counts().plot(kind='bar')
    plt.title("Emotion Distribution")

    # Alert distribution
    plt.subplot(1, 2, 2)
    pd.Series(alerts).value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title("Safety Alerts Distribution")

    plt.tight_layout()
    plt.show()

# %%
# %%capture
# !pip install pydub noisereduce librosa openai-whisper soundfile tensorflow scikit-learn matplotlib
# !apt install ffmpeg

# %%
# --------------------------
# 1. SETUP AND CONFIGURATION
# --------------------------
import os
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import librosa
import noisereduce as nr
import soundfile as sf
from pydub import AudioSegment
import whisper
import matplotlib.pyplot as plt

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Download and extract RAVDESS emotional speech dataset
# !wget https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip
# !unzip -q Audio_Speech_Actors_01-24.zip -d "/content/emotion_dataset"
# Out:
# --2025-03-10 10:39:28--  https://zenodo.org/record/1188976/files/Audio_Speech_Actors_01-24.zip
# Resolving zenodo.org (zenodo.org)... 188.185.45.92, 188.185.48.194, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.45.92|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/1188976/files/Audio_Speech_Actors_01-24.zip [following]
# --2025-03-10 10:39:28--  https://zenodo.org/records/1188976/files/Audio_Speech_Actors_01-24.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 208468073 (199M) [application/octet-stream]
# Saving to: ‘Audio_Speech_Actors_01-24.zip’
#
# Audio_Speech_Actors 100%[===================>] 198.81M   731KB/s    in 5m 7s
#
# 2025-03-10 10:44:36 (663 KB/s) - ‘Audio_Speech_Actors_01-24.zip’ saved [208468073/208468073]

# %%
# --------------------------
# 2. EMOTION DATASET PREPARATION
# --------------------------


def load_emotion_data(dataset_path):
    emotions = []
    features = []

    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".wav"):
                emotion_code = int(file.split("-")[2])
                emotions.append({
                    1: 'neutral', 2: 'calm', 3: 'happy',
                    4: 'sad', 5: 'angry', 6: 'fear',
                    7: 'disgust', 8: 'surprise'
                }[emotion_code])

                # Load and preprocess audio
                file_path = os.path.join(root, file)
                y, sr = librosa.load(file_path, sr=22050)
                y = nr.reduce_noise(y=y, sr=sr)

                # Extract MFCC features
                mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
                mfcc_processed = np.mean(mfcc.T, axis=0)

                features.append(mfcc_processed)

    return np.array(features), np.array(emotions)

# %%
# Load and prepare dataset
print("Loading emotion dataset...")
features, emotions = load_emotion_data("/content/emotion_dataset")
# Out:
# Loading emotion dataset...

# %%
# Encode labels
label_encoder = LabelEncoder()
encoded_emotions = label_encoder.fit_transform(emotions)

# %%
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    features, encoded_emotions, test_size=0.2, random_state=42
)

# %%
# --------------------------
# 3. EMOTION RECOGNITION MODEL
# --------------------------
def create_emotion_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# !pip install tensorflow==2.12.0
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.70.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.12.1)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.13.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)

# %%
# Create and train model
print("Training emotion recognition model...")
model = create_emotion_model((X_train.shape[1],), len(label_encoder.classes_))
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Training emotion recognition model...
# Epoch 1/50
# 36/36 [==============================] - 1s 10ms/step - loss: 62.3331 - accuracy: 0.1181 - val_loss: 6.7754 - val_accuracy: 0.1424
# Epoch 2/50
# 36/36 [==============================] - 0s 4ms/step - loss: 21.4594 - accuracy: 0.1354 - val_loss: 2.0789 - val_accuracy: 0.1146
# Epoch 3/50
# 36/36 [==============================] - 0s 4ms/step - loss: 6.7950 - accuracy: 0.1398 - val_loss: 2.0781 - val_accuracy: 0.1146
# Epoch 4/50
# 36/36 [==============================] - 0s 5ms/step - loss: 3.2996 - accuracy: 0.1398 - val_loss: 2.0770 - val_accuracy: 0.1146
# Epoch 5/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.7553 - accuracy: 0.1354 - val_loss: 2.0759 - val_accuracy: 0.1146
# Epoch 6/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.4357 - accuracy: 0.1337 - val_loss: 2.0750 - val_accuracy: 0.1146
# Epoch 7/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.3859 - accuracy: 0.1363 - val_loss: 2.0740 - val_accuracy: 0.1146
# Epoch 8/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.2513 - accuracy: 0.1424 - val_loss: 2.0733 - val_accuracy: 0.1146
# Epoch 9/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1899 - accuracy: 0.1363 - val_loss: 2.0727 - val_accuracy: 0.1146
# Epoch 10/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1573 - accuracy: 0.1311 - val_loss: 2.0719 - val_accuracy: 0.1146
# Epoch 11/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1758 - accuracy: 0.1424 - val_loss: 2.0716 - val_accuracy: 0.1146
# Epoch 12/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.1606 - accuracy: 0.1345 - val_loss: 2.0712 - val_accuracy: 0.1146
# Epoch 13/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.1127 - accuracy: 0.1372 - val_loss: 2.0709 - val_accuracy: 0.1146
# Epoch 14/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1001 - accuracy: 0.1398 - val_loss: 2.0705 - val_accuracy: 0.1146
# Epoch 15/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1302 - accuracy: 0.1372 - val_loss: 2.0702 - val_accuracy: 0.1146
# Epoch 16/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.1314 - accuracy: 0.1372 - val_loss: 2.0699 - val_accuracy: 0.1146
# Epoch 17/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.1117 - accuracy: 0.1354 - val_loss: 2.0699 - val_accuracy: 0.1146
# Epoch 18/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.1072 - accuracy: 0.1380 - val_loss: 2.0697 - val_accuracy: 0.1146
# Epoch 19/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.0916 - accuracy: 0.1345 - val_loss: 2.0696 - val_accuracy: 0.1146
# Epoch 20/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.0909 - accuracy: 0.1406 - val_loss: 2.0695 - val_accuracy: 0.1146
# Epoch 21/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.0842 - accuracy: 0.1363 - val_loss: 2.0695 - val_accuracy: 0.1146
# Epoch 22/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0871 - accuracy: 0.1389 - val_loss: 2.0694 - val_accuracy: 0.1146
# Epoch 23/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0834 - accuracy: 0.1389 - val_loss: 2.0694 - val_accuracy: 0.1146
# Epoch 24/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0755 - accuracy: 0.1398 - val_loss: 2.0693 - val_accuracy: 0.1146
# Epoch 25/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0744 - accuracy: 0.1398 - val_loss: 2.0693 - val_accuracy: 0.1146
# Epoch 26/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.0651 - accuracy: 0.1398 - val_loss: 2.0694 - val_accuracy: 0.1146
# Epoch 27/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.0738 - accuracy: 0.1372 - val_loss: 2.0695 - val_accuracy: 0.1146
# Epoch 28/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.0649 - accuracy: 0.1380 - val_loss: 2.0695 - val_accuracy: 0.1146
# Epoch 29/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.0815 - accuracy: 0.1398 - val_loss: 2.0695 - val_accuracy: 0.1146
# Epoch 30/50
# 36/36 [==============================] - 0s 5ms/step - loss: 2.0802 - accuracy: 0.1406 - val_loss: 2.0696 - val_accuracy: 0.1146
# Epoch 31/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0707 - accuracy: 0.1398 - val_loss: 2.0696 - val_accuracy: 0.1146
# Epoch 32/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0832 - accuracy: 0.1389 - val_loss: 2.0697 - val_accuracy: 0.1146
# Epoch 33/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0746 - accuracy: 0.1406 - val_loss: 2.0697 - val_accuracy: 0.1146
# Epoch 34/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0713 - accuracy: 0.1398 - val_loss: 2.0698 - val_accuracy: 0.1146
# Epoch 35/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0682 - accuracy: 0.1233 - val_loss: 2.0699 - val_accuracy: 0.1146
# Epoch 36/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0746 - accuracy: 0.1389 - val_loss: 2.0698 - val_accuracy: 0.1146
# Epoch 37/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0720 - accuracy: 0.1302 - val_loss: 2.0698 - val_accuracy: 0.1146
# Epoch 38/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0613 - accuracy: 0.1389 - val_loss: 2.0699 - val_accuracy: 0.1146
# Epoch 39/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0749 - accuracy: 0.1406 - val_loss: 2.0700 - val_accuracy: 0.1146
# Epoch 40/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0618 - accuracy: 0.1380 - val_loss: 2.0701 - val_accuracy: 0.1146
# Epoch 41/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0622 - accuracy: 0.1406 - val_loss: 2.0701 - val_accuracy: 0.1146
# Epoch 42/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0679 - accuracy: 0.1380 - val_loss: 2.0703 - val_accuracy: 0.1146
# Epoch 43/50
# 36/36 [==============================] - 0s 4ms/step - loss: 2.0633 - accuracy: 0.1398 - val_loss: 2.0702 - val_accuracy: 0.1146
# Epoch 44/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0587 - accuracy: 0.1380 - val_loss: 2.0704 - val_accuracy: 0.1076
# Epoch 45/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0618 - accuracy: 0.1302 - val_loss: 2.0702 - val_accuracy: 0.1146
# Epoch 46/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0603 - accuracy: 0.1345 - val_loss: 2.0704 - val_accuracy: 0.1076
# Epoch 47/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0666 - accuracy: 0.1267 - val_loss: 2.0704 - val_accuracy: 0.1146
# Epoch 48/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0776 - accuracy: 0.1345 - val_loss: 2.0705 - val_accuracy: 0.1076
# Epoch 49/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0656 - accuracy: 0.1233 - val_loss: 2.0706 - val_accuracy: 0.1076
# Epoch 50/50
# 36/36 [==============================] - 0s 3ms/step - loss: 2.0662 - accuracy: 0.1372 - val_loss: 2.0705 - val_accuracy: 0.1076

# %%
# Save model
model.save('/content/drive/MyDrive/emotion_model.h5')

# %%
# --------------------------
# 4. AUDIO PROCESSING PIPELINE
# --------------------------
class SafetyAnalyzer:
    def __init__(self):
        self.panic_words = {
            "help", "fire", "emergency", "danger", "run", "stop", "police",
            "watch out", "look out", "get down", "move", "duck", "stay back",
            "back off", "stay away", "call 911", "call an ambulance",
            "call the police", "call for help", "mayday", "sos", "alert"
        }
        self.whisper_model = whisper.load_model("base")
        self.emotion_model = tf.keras.models.load_model('/content/drive/MyDrive/emotion_model.h5')
        self.label_encoder = label_encoder

    def process_audio(self, input_path):
        # Convert to WAV
        if input_path.endswith(".opus"):
            audio = AudioSegment.from_file(input_path)
            wav_path = input_path.replace(".opus", ".wav")
            audio.export(wav_path, format="wav")
            os.remove(input_path)
            input_path = wav_path

        # Noise reduction
        y, sr = librosa.load(input_path, sr=22050)
        y_clean = nr.reduce_noise(y=y, sr=sr)
        clean_path = input_path.replace(".wav", "_clean.wav")
        sf.write(clean_path, y_clean, sr)

        return clean_path

    def analyze_emotion(self, audio_path):
        y, sr = librosa.load(audio_path, sr=22050)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
        features = np.mean(mfcc.T, axis=0)
        prediction = self.emotion_model.predict(np.expand_dims(features, axis=0))
        emotion = self.label_encoder.inverse_transform([np.argmax(prediction)])[0]
        confidence = np.max(prediction)
        return emotion, confidence

    def transcribe_audio(self, audio_path):
        result = self.whisper_model.transcribe(audio_path)
        return result["text"]

    def analyze_safety(self, audio_path):
        # Process audio
        clean_path = self.process_audio(audio_path)

        # Emotion analysis
        emotion, confidence = self.analyze_emotion(clean_path)

        # Transcription analysis
        transcription = self.transcribe_audio(clean_path)
        panic_detected = [word for word in self.panic_words
                          if word in transcription.lower()]

        # Generate report
        report = {
            "file_path": audio_path,
            "emotion": emotion,
            "confidence": float(confidence),
            "transcription": transcription,
            "panic_words": panic_detected,
            "requires_attention": any(panic_detected) or emotion in ['fear', 'angry']
        }

        return report

# %%
# --------------------------
# 5. MAIN EXECUTION
# --------------------------
def analyze_directory(directory_path):
    analyzer = SafetyAnalyzer()
    results = []

    for root, _, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".wav"):
                file_path = os.path.join(root, file)
                try:
                    report = analyzer.analyze_safety(file_path)
                    results.append(report)

                    if report["requires_attention"]:
                        print(f"🚨 SAFETY ALERT: {file_path}")
                        print(f"Detected emotion: {report['emotion']} ({report['confidence']:.2%})")
                        print(f"Panic words detected: {report['panic_words']}")
                        print(f"Transcription: {report['transcription']}\n")

                except Exception as e:
                    print(f"Error processing {file_path}: {str(e)}")

    return results

# %%
# Run analysis on your audio directory
audio_directory = "/content/drive/MyDrive/audiosdata/audiototext/audio data"
results = analyze_directory(audio_directory)
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:05<00:00, 27.9MiB/s]
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.41.46_eeea78d8.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me someone is following
#
# 1/1 [==============================] - 0s 22ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.41.46_da5dbe97.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  I am danger.
#
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.00_a799a120.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  help he is attacking me
#
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.01_43b7e3fa.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  Someone shot me, he's dangerous!
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.23_59527b48.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Help! He won't stop staring!
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_f664a4c9.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'danger']
# Transcription:  I need help. Be dangerous.
#
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_b42e545a.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  help is getting too close
#
# 1/1 [==============================] - 0s 62ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.09_550e24e4.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need help, right now.
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_89a193b1.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need help, right now.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.09_27ec7fa3.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need help, right now.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.54_1dd58337.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I don't feel safe, help me now!
#
# 1/1 [==============================] - 0s 47ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.54_706524ac.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I don't feel safe, help me now!
#
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_8e11f002.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Help! You won't stop threatening me!
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_0502822e.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need help now. He's violent.
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.47_be45204b.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'danger']
# Transcription:  Please, Alabama, danger, please, help!
#
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.46_8c3a99f2.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  He's chasing me help help
#
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.47_63a6ceb9.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'run']
# Transcription:  I think I'm drunk. Help me.
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_93a40aee.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Guys, Gary please help.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_0a954420.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Go away! Someone help me please!
#
# 1/1 [==============================] - 0s 25ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_e9d168b4.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['police', 'help']
# Transcription:  and need help please go police
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_8756b33a.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me please, you will leave me alone.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.52_3064bcfa.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Here we'll stop. Try to help.
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_02ec5ce9.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  please don't touch me, please someone help
#
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 26ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.41.46_eeea78d8_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me summon his following
#
# 1/1 [==============================] - 0s 28ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.41.46_da5dbe97_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  We are in danger!
#
# 1/1 [==============================] - 0s 26ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.00_a799a120_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help please untact me!
#
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.01_43b7e3fa_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  Someone shot me with his dangerous!
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.23_59527b48_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Help! He won't stop staring!
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_f664a4c9_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'danger']
# Transcription:  I need help. Be dangerous.
#
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_b42e545a_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  help is getting too close
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.54_1dd58337_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I don't want to be seen if help me now!
#
# 1/1 [==============================] - 0s 41ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.54_706524ac_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I don't want to be seen if help me now!
#
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_8e11f002_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Help! You won't stop threatening me!
#
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_0502822e_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need help now, he's violin!
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.47_be45204b_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  Please, our bond in danger, please hope.
#
# 1/1 [==============================] - 0s 50ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.46_8c3a99f2_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  He's chasing me help help.
#
# 1/1 [==============================] - 0s 22ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.47_63a6ceb9_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'run']
# Transcription:  I think I'm drunk, help me.
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_93a40aee_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  God's caring, please help.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.49_680bbce7_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['sos']
# Transcription:  Thisoshi cat called my god hees
#
# 1/1 [==============================] - 0s 31ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_0a954420_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Go away! Someone help me please!
#
# 1/1 [==============================] - 0s 27ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_e9d168b4_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['police', 'help']
# Transcription:  and need help please for police
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_8756b33a_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me please you will leave me alone.
#
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.52_3064bcfa_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Hands top, try to help.
#
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_02ec5ce9_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Instagram, that's me, please, someone help.
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.41.46_eeea78d8_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me summon this following
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.00_a799a120_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help, please attack me!
#
# 1/1 [==============================] - 0s 25ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.01_43b7e3fa_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  Não mitä, pires dangerous! E HOURS coû
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.01_ec885ad6_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  He's in service, and he'll help me!
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 50ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.23_59527b48_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['stop']
# Transcription:  Hell, people must stop staring.
#
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.10_b42e545a_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  help is getting too close
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 61ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_8e11f002_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help! You know what I'm talking about!
#
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.46_8c3a99f2_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  He's chasing me out, help!
#
# 1/1 [==============================] - 0s 48ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.47_63a6ceb9_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I think I'm trapped, help me.
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_93a40aee_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  God's helps me please…
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_0a954420_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Go away, someone help me please.
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_8756b33a_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Help me please you leave me alone.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.51_91e5a9ec_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['danger']
# Transcription:  Someone am a danger.
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.50_02ec5ce9_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  It's done, that's really strange. Someone help.
#
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.01_ec885ad6_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  These interviews will help me.
#
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.42.23_59527b48_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['stop']
# Transcription:  Hell, people will stop staring.
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 26ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.13_b167bafa_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['stop']
# Transcription:  பھیک Maukt stop
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-27 at 21.44.56_0502822e_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  I need some help. He's walking.
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.46_8c3a99f2_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  He's trusting me how it helps.
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 24ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.48_0a954420_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help']
# Transcription:  Go away, someone help me please.
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 51ms/step
# 🚨 SAFETY ALERT: /content/drive/MyDrive/audiosdata/audiototext/audio data/WhatsApp Audio 2025-02-28 at 00.35.52_3064bcfa_clean_clean_clean.wav
# Detected emotion: calm (13.83%)
# Panic words detected: ['help', 'stop']
# Transcription:  Stop! Please help!
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def visualize_results(results):
    if not results:
        print("No results to visualize.")
        return

    emotions = [r['emotion'] for r in results if 'emotion' in r]
    alerts = [r['requires_attention'] for r in results if 'requires_attention' in r]

    if not emotions:
        print("No emotion data available.")
        return

    if not alerts:
        print("No safety alert data available.")
        return

    plt.figure(figsize=(15, 5))

    # Emotion distribution
    plt.subplot(1, 2, 1)
    pd.Series(emotions).value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title("Emotion Distribution")
    plt.xlabel("Emotions")
    plt.ylabel("Count")

    # Alert distribution
    plt.subplot(1, 2, 2)
    pd.Series(alerts).value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['red', 'green'])
    plt.title("Safety Alerts Distribution")

    plt.tight_layout()
    plt.show()
